# %% [markdown]
# **Count:** 1
# **Level :** Biginner

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### What is clustering?

# %% [markdown]
# **Clustering :** The procedure of partitioning a set of observations into a set of meaningful subclassess. Meaningful means describing similarity between the classes. These procedure help to explore natural structure in dataset.

# %% [markdown]
# ### What are the applications of clustering?

# %% [markdown]
# Medicine - Type of tissues
# Business - Type of customer segments
# Social Science - Social issues

# %% [markdown]
# ### What are the typical cluster models ?

# %% [markdown]
# Typical model:
# - **Connectivity models:** for example, hierarchical clustering builds models based on distance connectivity.
# - **Centroid models:** for example, the k-means algorithm represents each cluster by a single mean vector.
# - **Distribution models:** clusters are modeled using statistical distributions, such as multivariate normal distributions used by the expectation-maximization algorithm.
# - **Density models:** for example, DBSCAN and OPTICS defines clusters as connected dense regions in the data space.
# - **Subspace models:** in biclustering (also known as co-clustering or two-mode-clustering), clusters are modeled with both cluster members and relevant attributes.
# - **Group models:** some algorithms do not provide a refined model for their results and just provide the grouping information.
# - **Graph-based models:** a clique, that is, a subset of nodes in a graph such that every two nodes in the subset are connected by an edge can be considered as a prototypical form of cluster. Relaxations of the complete connectivity requirement (a fraction of the edges can be missing) are known as quasi-cliques, as in the HCS clustering algorithm.
# - **Neural models:** the most well known unsupervised neural network is the self-organizing map and these models can usually be characterized as similar to one or more of the above models, and including subspace models when neural networks implement a form of Principal Component Analysis or Independent Component Analysis.

# %% [markdown]
# ### Difference between partitioning/centroid vs distribution model based clustering?

# %% [markdown]
# Explained with examples of gender data:

# %%
df_gender = pd.read_csv('../data/gender.csv')
df_gender['BMI'] = df_gender['BMI'] * 1000
df_gender.head(5)
# Out:
#   Gender     Height      Weight        BMI  probability
# 0   Male  73.847017  241.893563  44.356615     0.000006
# 1   Male  68.781904  162.310473  34.308217     0.605953
# 2   Male  74.110105  212.740856  38.734329     0.000026
# 3   Male  71.730978  220.042470  42.765446     0.000363
# 4   Male  69.881796  206.349801  42.254789     0.004612

# %% [markdown]
# Plot BMI vs Weight?

# %%
df_gender.plot(x='Weight',y='BMI',kind='scatter',alpha=0.2);

# %% [markdown]
# How to run Kmeans and find two cluster?

# %%
from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler

X = df_gender[['Height','Weight','BMI']]

scaler = StandardScaler().fit(X)

y = KMeans(n_clusters=2, random_state=12).fit_predict(scaler.transform(X))

df_gender['kmean_cluster'] = y

ax1 = df_gender[df_gender['kmean_cluster']==1].plot(x='Weight',y='BMI',kind='scatter',alpha=0.2,color='red');
df_gender[df_gender['kmean_cluster']==0].plot(x='Weight',y='BMI',kind='scatter',alpha=0.2,ax=ax1,color='black');
